# %% [markdown]
# #### Pandas import and declare dataframe

# %%
import pandas as pd
df=pd.read_csv("imdb_top_1000.csv")

# %% [markdown]
# #### Let see our df's first 5 lines

# %%
df.head(5)
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# ...

# %% [markdown]
# #### Lets see our df's last 5 lines

# %%
df.tail(5)
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 995  Breakfast at Tiffany's          1961           A  115 min
# 996                   Giant          1956           G  201 min
# 997   From Here to Eternity          1953      Passed  118 min
# 998                Lifeboat          1944         NaN   97 min
# 999            The 39 Steps          1935         NaN   86 min
#
#                         Genre  IMDB_Rating  \
# 995    Comedy, Drama, Romance          7.6
# 996            Drama, Western          7.6
# 997       Drama, Romance, War          7.6
# 998                Drama, War          7.6
# 999  Crime, Mystery, Thriller          7.6
#
#                                               Overview  Meta_score  \
# 995  A young New York socialite becomes interested ...        76.0
# 996  Sprawling epic covering the life of a Texas ca...        84.0
# 997  In Hawaii in 1941, a private is cruelly punish...        85.0
# ...

# %% [markdown]
# #### Lets see our df's shape and len

# %%
df.shape #row and column
len(df) #just row
# Out:
# 1000

# %% [markdown]
# #### df's Column Titles

# %%
df.columns
# Out:
# Index(['Series_Title', 'Released_Year', 'Certificate', 'Runtime', 'Genre',
#        'IMDB_Rating', 'Overview', 'Meta_score', 'Director', 'Star1', 'Star2',
#        'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %% [markdown]
# #### df's Data Types

# %%
df.dtypes
# Out:
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross             object
# dtype: object

# %% [markdown]
# #### df's Cell Which Is Null

# %%
df.isnull()
# Out:
#      Series_Title  Released_Year  Certificate  Runtime  Genre  IMDB_Rating  \
# 0           False          False        False    False  False        False
# 1           False          False        False    False  False        False
# 2           False          False        False    False  False        False
# 3           False          False        False    False  False        False
# 4           False          False        False    False  False        False
# ..            ...            ...          ...      ...    ...          ...
# 995         False          False        False    False  False        False
# 996         False          False        False    False  False        False
# 997         False          False        False    False  False        False
# 998         False          False         True    False  False        False
# 999         False          False         True    False  False        False
#
# ...

# %% [markdown]
# #### Get a Column from df

# %%
df["Series_Title"]
# Out:
# 0      The Shawshank Redemption
# 1                 The Godfather
# 2               The Dark Knight
# 3        The Godfather: Part II
# 4                  12 Angry Men
#                  ...
# 995      Breakfast at Tiffany's
# 996                       Giant
# 997       From Here to Eternity
# 998                    Lifeboat
# 999                The 39 Steps
# Name: Series_Title, Length: 1000, dtype: object

# %% [markdown]
# #### Get a Column's first 5 lines

# %%
df["Series_Title"][:5]
# Out:
# 0    The Shawshank Redemption
# 1               The Godfather
# 2             The Dark Knight
# 3      The Godfather: Part II
# 4                12 Angry Men
# Name: Series_Title, dtype: object

# %% [markdown]
# #### Declare df2 from df

# %%
df2=df[['Series_Title','Released_Year']]
df2
# Out:
#                  Series_Title Released_Year
# 0    The Shawshank Redemption          1994
# 1               The Godfather          1972
# 2             The Dark Knight          2008
# 3      The Godfather: Part II          1974
# 4                12 Angry Men          1957
# ..                        ...           ...
# 995    Breakfast at Tiffany's          1961
# 996                     Giant          1956
# 997     From Here to Eternity          1953
# 998                  Lifeboat          1944
# 999              The 39 Steps          1935
#
# [1000 rows x 2 columns]

# %% [markdown]
# #### Sort df according to released years

# %%
df.sort_values('Released_Year',ascending=False)
# Out:
#                      Series_Title Released_Year Certificate  Runtime  \
# 966                     Apollo 13            PG           U  140 min
# 20                Soorarai Pottru          2020           U  153 min
# 612    The Trial of the Chicago 7          2020           R  129 min
# 613                          Druk          2020         NaN  117 min
# 18                       Hamilton          2020       PG-13  160 min
# ..                            ...           ...         ...      ...
# 193                 The Gold Rush          1925      Passed   95 min
# 194                  Sherlock Jr.          1924      Passed   45 min
# 568                     Nosferatu          1922         NaN   94 min
# 127                       The Kid          1921      Passed   68 min
# 321  Das Cabinet des Dr. Caligari          1920         NaN   76 min
#
#                          Genre  IMDB_Rating  \
# 966  Adventure, Drama, History          7.6
# 20                       Drama          8.6
# ...

# %% [markdown]
# #### Number of the films according to the years

# %%
df["Released_Year"].value_counts()
# Out:
# Released_Year
# 2014    32
# 2004    31
# 2009    29
# 2013    28
# 2016    28
#         ..
# 1926     1
# 1936     1
# 1924     1
# 1921     1
# PG       1
# Name: count, Length: 100, dtype: int64

# %% [markdown]
# #### Get A Column Info From An Index

# %%
df['IMDB_Rating'][1]
# Out:
# 9.2

# %% [markdown]
# #### Get A Line Which You Know the Series Title

# %%
df.loc[df['Series_Title']=="The Godfather"]["IMDB_Rating"]
# Out:
# 1    9.2
# Name: IMDB_Rating, dtype: float64

# %%
df.loc[df['Series_Title']=="The Godfather"]
# Out:
#     Series_Title Released_Year Certificate  Runtime         Genre  \
# 1  The Godfather          1972           A  175 min  Crime, Drama
#
#    IMDB_Rating                                           Overview  Meta_score  \
# 1          9.2  An organized crime dynasty's aging patriarch t...       100.0
#
#                Director          Star1      Star2       Star3         Star4  \
# 1  Francis Ford Coppola  Marlon Brando  Al Pacino  James Caan  Diane Keaton
#
#    No_of_Votes        Gross
# 1      1620367  134,966,411

# %%
type(df.loc[df['Series_Title']=="The Godfather"])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### Films which has more than 8 of imdb and more than 100000 votes

# %%
df.loc[(df['IMDB_Rating']>=8) & (df['No_of_Votes']>=100000)]
# Out:
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# 3      The Godfather: Part II          1974           A  202 min
# 4                12 Angry Men          1957           U   96 min
# ..                        ...           ...         ...      ...
# 432                        8½          1963         NaN  138 min
# 446             Roman Holiday          1953         NaN  118 min
# 450                      Rope          1948           A   80 min
# 456        The Maltese Falcon          1941         NaN  100 min
# 458          The Wizard of Oz          1939           U  102 min
#
#                           Genre  IMDB_Rating  \
# 0                         Drama          9.3
# 1                  Crime, Drama          9.2
# 2          Action, Crime, Drama          9.0
# ...

# %% [markdown]
# #### Films which has more than 8 of imdb and more than 300000000 gross

# %%
df.loc[(df['IMDB_Rating']>=8) & (df['Gross']>=3000000)] # Error cause of type object

# %%
# Remove commas from our df and convert to float
df['Gross']=df['Gross'].str.replace(",","")
df['Gross']=pd.to_numeric(df['Gross'])
type(df["Gross"][0])

# %%
df.loc[(df['IMDB_Rating']>=8) & (df['Gross']>=300000000)] # Error cause of type object
# Out:
#                                           Series_Title Released_Year  \
# 2                                      The Dark Knight          2008
# 5        The Lord of the Rings: The Return of the King          2003
# 10   The Lord of the Rings: The Fellowship of the Ring          2001
# 11                                        Forrest Gump          1994
# 13               The Lord of the Rings: The Two Towers          2002
# 29                                           Star Wars          1977
# 33                                               Joker          2019
# 43                                       The Lion King          1994
# 59                                   Avengers: Endgame          2019
# 60                              Avengers: Infinity War          2018
# 63                               The Dark Knight Rises          2012
# 109         Star Wars: Episode VI - Return of the Jedi          1983
# 151                                        Toy Story 3          2010
# ...

# %% [markdown]
# #### Create A Data Frame Manually

# %%
import random
randomlist1=random.sample(range(15,25),2)
randomlist2=random.sample(range(15,25),2)
randomlist1
# Out:
# [19, 16]

# %%
randomlist2
# Out:
# [24, 21]

# %%
randomlistoflists=[randomlist1,randomlist2]
randomlistoflists
# Out:
# [[19, 16], [24, 21]]

# %%
columns=["Sıcaklık 1.Gün","Sıcaklık 2.Gün"]
mydataframe=pd.DataFrame(randomlistoflists,index=["İstanbul","Ankara"],columns=columns)
mydataframe
# Out:
#           Sıcaklık 1.Gün  Sıcaklık 2.Gün
# İstanbul              19              16
# Ankara                24              21

# %%
type(mydataframe)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame
