# %%
import numpy as np

# %%
income=np.random.normal(5000,2000,1000)
income
# Out:
# array([ 3408.61539799,  1599.58153865,  3224.95227243,  4524.43140454,
#         7508.01214821,  4877.1322179 ,  3959.83821885,  4106.70052416,
#         8950.47586207,  6261.77129122,  3857.71075245,  3323.0743862 ,
#         -249.04927598,  4766.93885658,  1219.1748142 ,  6467.2447587 ,
#         4520.06384376,  7493.9976499 ,  6530.73967748,  1236.62049157,
#         5833.3060829 ,  5491.95076628,  3542.63873142,  3266.60564919,
#         6558.36851548,  5616.60018786,  2537.77483017,  3498.49869932,
#         1052.02780125,  5843.02518224,  2176.63552471,  6636.54273534,
#         6796.46711701,  4392.25147798,  6781.71050797,  5724.37048698,
#         4350.96841301,  4447.43205968,  5048.75981563, 10517.73713285,
#         6777.29630567,  2594.90131179,  3360.25623804,  6164.47490062,
#         8898.36173994,  3811.48206972,  6991.34699897,  6672.81367315,
#         4986.21651861,  7891.25490067,  6361.50018824,  5994.84275291,
# ...

# %%
np.mean(income)
# Out:
# 4969.655511407758

# %%
import matplotlib.pyplot as plt
plt.hist(income,100)
plt.show()

# %%
np.median(income)
# Out:
# 5012.559368733671

# %%
income=np.append(income,[10000000])
np.mean(income)
# Out:
# 14954.700810597162

# %% [markdown]
# Median and Mean, sometimes median can be more trustful

# %%
np.median(income)
# Out:
# 5013.669551887294

# %%
ages=np.random.randint(7,18,size=300)

from scipy import stats
stats.mode(ages)
# Out:
# ModeResult(mode=12, count=38)

# %%
income.var()
# Out:
# 99705120351.09662

# %%
income.std()
# Out:
# 315761.1761301516
